# %% [markdown]
# THIS CODE BELONGS TO PIYUSH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Sumit\OneDrive\Documents\GITHUB IBM DA\India-Energy-Analytics-Model\India_monthly_data.csv')

# %%
df2 = pd.read_csv(r'C:\Users\Sumit\OneDrive\Documents\GITHUB IBM DA\India-Energy-Analytics-Model\CEA_DGR_data.csv')

# %%
print(df.head())
# Out:
#    yyyymm  PET.LPG.CON  PET.NAP.CON  PET.MSP.CON  PET.ATF.CON  PET.SKO.CON  \
# 0  199804    394.46856    596.08700    447.68483    178.09228   1021.88915
# 1  199805    392.53362    709.01074    489.86105    177.90225   1128.39596
# 2  199806    381.08117    627.70891    461.98671    165.27390   1000.89840
# 3  199807    438.12152    806.93441    451.38282    168.70792    934.15442
# 4  199808    415.30768    750.95225    449.51906    169.77698    969.68047
#
#    PET.HSD.CON  PET.LDO.CON  PET.LUB.CON  PET.SEC.CON  ...  \
# 0   3193.43381     89.10071     56.26691    835.62215  ...
# 1   3273.82226     99.72218     78.27624    951.92611  ...
# 2   3192.91495     99.90179     93.20537    930.76007  ...
# 3   2920.60897    108.88729     77.26600   1090.23940  ...
# 4   2625.25393    111.39742     88.29637   1060.63881  ...
#
#    IDY.PRD.OEA.CEM.OLD  IDY.PRD.OEA.ELY.OLD  IDY.PRD.OEA.COL  IDY.PRD.OEA.CRU  \
# 0                  NaN                  NaN              NaN              NaN
# 1                  NaN                  NaN              NaN              NaN
# 2                  NaN                  NaN              NaN              NaN
# 3                  NaN                  NaN              NaN              NaN
# 4                  NaN                  NaN              NaN              NaN
#
#    IDY.PRD.OEA.GAS  IDY.PRD.OEA.PET  IDY.PRD.OEA.FER  IDY.PRD.OEA.STL  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    IDY.PRD.OEA.CEM  IDY.PRD.OEA.ELY
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
# [5 rows x 203 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Columns: 203 entries, yyyymm to IDY.PRD.OEA.ELY
# dtypes: float64(202), int64(1)
# memory usage: 499.7 KB
# None

# %%
print(df.describe())
# Out:
#               yyyymm  PET.LPG.CON  PET.NAP.CON  PET.MSP.CON  PET.ATF.CON  \
# count     315.000000   315.000000   315.000000   315.000000   315.000000
# mean   201094.104762  1363.470930  1034.352649  1439.152793   406.649982
# std       759.700388   646.572033   150.810698   836.967249   174.650046
# min    199804.000000   381.081170   596.087000   439.762890    55.179245
# 25%    200410.500000   834.650000   932.800000   692.000000   226.450000
# 50%    201105.000000  1232.300000  1037.800000  1201.900000   411.755138
# 75%    201711.500000  1936.359991  1130.108559  2144.486710   536.250000
# max    202406.000000  2697.609874  1465.188188  3462.927638   757.865799
#
#        PET.SKO.CON  PET.HSD.CON  PET.LDO.CON  PET.LUB.CON  PET.SEC.CON  ...  \
# count   315.000000   315.000000   315.000000   315.000000   315.000000  ...
# mean    597.180461  5021.800140    71.124803   222.786524   801.483477  ...
# std     302.795477  1606.976639    40.498423   101.632668   257.506914  ...
# min      23.241758  2564.800000    20.300000    55.619420   283.008625  ...
# 25%     314.062940  3377.500000    37.600000   130.845135   543.449695  ...
# 50%     709.000000  5047.800000    57.334934   215.400000   828.000000  ...
# 75%     797.600000  6379.800000   102.774075   301.690037  1047.700000  ...
# max    1128.395960  8407.652820   194.900000   538.109764  1271.200000  ...
#
#        IDY.PRD.OEA.CEM.OLD  IDY.PRD.OEA.ELY.OLD  IDY.PRD.OEA.COL  \
# count           156.000000           156.000000       158.000000
# mean          17899.942308         70575.870321        59.404076
# std            4380.476164         15983.675987        16.176210
# min            9355.000000         46015.760000        30.802000
# 25%           14332.500000         57857.557500        47.217000
# 50%           18055.500000         67213.245000        55.955000
# 75%           21498.250000         82750.285000        68.433750
# max           27050.000000        107785.500000       117.647000
#
#        IDY.PRD.OEA.CRU  IDY.PRD.OEA.GAS  IDY.PRD.OEA.PET  IDY.PRD.OEA.FER  \
# count       158.000000       158.000000       158.000000       158.000000
# mean       2846.965114      2824.060909     20224.234826      3511.367722
# std         300.435881       399.980644      2146.416232       424.844206
# min        2161.366000      2066.074000     15561.139611      2307.400000
# 25%        2526.320875      2602.253500     18479.702868      3288.225000
# 50%        2911.521000      2744.939390     20194.706000      3495.500000
# 75%        3115.551000      2908.596500     22061.836750      3767.425000
# max        3277.374000      4043.826000     24886.792000      4466.600000
#
#        IDY.PRD.OEA.STL  IDY.PRD.OEA.CEM  IDY.PRD.OEA.ELY
# count       158.000000       158.000000       158.000000
# mean       8887.069620     25853.683544    107046.401582
# std        1980.190649      5631.956951     22857.205468
# min        1697.000000      4305.000000     68762.880000
# 25%        7442.750000     22010.250000     90880.000000
# 50%        8710.000000     24803.000000    107073.500000
# 75%       10034.000000     29418.000000    121486.952500
# max       13741.000000     41968.000000    166181.030000
#
# [8 rows x 203 columns]

# %%
print("Removing rows with missing values")

rows_before = df.shape[0]
print(f"Rows before cleaning: {rows_before}")

df1_cleaned = df.dropna(subset=["PET.LPG.CON","PET.NAP.CON","PET.MSP.CON","PET.ATF.CON","PET.SKO.CON","PET.HSD.CON","PET.LDO.CON","PET.LUB.CON","PET.SEC.CON","PET.BIT.CON","PET.PCK.CON","PET.OTH.CON","PET.TOT.CON","PET.TOT.PRD"])

rows_after = df1_cleaned.shape[0]
print(f"Rows after cleaning (dropping): {rows_after}")
# Out:
# Removing rows with missing values
# Rows before cleaning: 315
# Rows after cleaning (dropping): 170

# %%
print("Removing rows with missing values")

rows_before = df.shape[0]
print(f"Rows before cleaning: {rows_before}")

df2_cleaned = df.dropna(subset=["GAS.PRD.GRS","GAS.PRD.NET","GAS.IMP","GAS.IMP.PRV","GAS.CON.PWR","GAS.CON.CGD","GAS.CON.REF","GAS.CON.INT","GAS.CON.TEA","GAS.CON.IND","GAS.CON.MFG","GAS.CON.OTH","GAS.CON.FRT","GAS.CON.PET","GAS.CON.SHR","GAS.CON.IRN","GAS.CON.TOT"])

rows_after = df2_cleaned.shape[0]
print(f"Rows after cleaning (dropping): {rows_after}")
# Out:
# Removing rows with missing values
# Rows before cleaning: 315
# Rows after cleaning (dropping): 111

# %%
print("Removing rows with missing values")

rows_before = df.shape[0]
print(f"Rows before cleaning: {rows_before}")

df3_cleaned = df.dropna(subset=["COL.HRD.PRD.CIL.REV","COL.HRD.DES.CIL.REV","COL.HRD.PRD.CIL.PRV","COL.HRD.DES.CIL.PRV","COL.HRD.PRD.SCCL.PRV","COL.HRD.DES.SCCL.PRV","COL.HRD.PRD.SCCL.REV","COL.HRD.DES.SCCL.REV","COL.HRD.IMP.CIS","COL.HRD.EXP.CIS","COL.HRD.IMP.COK.DOC","COL.HRD.IMP.STM.DOC","COL.HRD.IMP.TOT.DOC","COL.HRD.PRD.PRV","COL.LIG.PRD.PRV","COL.HRD.PRD.REV","COL.LIG.PRD.REV","COL.HRD.PRD.ECL.MCL","COL.HRD.PRD.BCCL.MCL","COL.HRD.PRD.CCL.MCL","COL.HRD.PRD.NCL.MCL","COL.HRD.PRD.WCL.MCL","COL.HRD.PRD.SECL.MCL","COL.HRD.PRD.MCL.MCL","COL.HRD.PRD.NEC.MCL","COL.HRD.PRD.CIL.MCL","COL.HRD.PRD.SCCL.MCL","COL.HRD.PRD.CaptivesOthers.MCL","COL.HRD.PRD.GrandTotal.MCL","COL.HRD.DES.ECL.MCL","COL.HRD.DES.BCCL.MCL","COL.HRD.DES.CCL.MCL","COL.HRD.DES.NCL.MCL","COL.HRD.DES.WCL.MCL","COL.HRD.DES.SECL.MCL","COL.HRD.DES.MCL.MCL","COL.HRD.DES.NEC.MCL","COL.HRD.DES.CIL.MCL","COL.HRD.DES.SCCL.MCL","COL.HRD.DES.CaptivesOthers.MCL","COL.HRD.DES.GrandTotal.MCL","COL.LIG.PRD.NLCIL.MCL","COL.LIG.PRD.GMDCL.MCL","COL.LIG.PRD.GIPCL.MCL","COL.LIG.PRD.RSMML.MCL","COL.LIG.PRD.BLMCL.MCL","COL.LIG.PRD.GHCL.MCL","COL.LIG.PRD.VSLignite.MCL","COL.LIG.PRD.GSPL.MCL","COL.LIG.PRD.GrandTotal.MCL","COL.LIG.DES.NLCIL.MCL","COL.LIG.DES.GMDCL.MCL","COL.LIG.DES.GIPCL.MCL","COL.LIG.DES.RSMML.MCL","COL.LIG.DES.BLMCL.MCL","COL.LIG.DES.GHCL.MCL","COL.LIG.DES.VSLignite.MCL","COL.LIG.DES.GSPL.MCL","COL.LIG.DES.GrandTotal.MCL","COL.HRD.PRD.UNS","COL.LIG.PRD.UNS","COL.HRD.PRD.CAP.CAB","COL.HRD.PRD.CIL.MCL.YTD","COL.HRD.PRD.SCCL.MCL.YTD","COL.HRD.PRD.CAP.MCL.YTD","COL.HRD.PRD.OTH.MCL.YTD","COL.HRD.PRD.TOT.MCL.YTD","COL.HRD.DES.CIL.MCL.YTD","COL.HRD.DES.SCCL.MCL.YTD","COL.HRD.DES.CAP.MCL.YTD","COL.HRD.DES.OTH.MCL.YTD","COL.HRD.DES.TOT.MCL.YTD","COL.HRD.CON.PWR.ALL","COL.HRD.IMP.PWR.ALL","COL.HRD.STC.PWR.LNK","COL.HRD.STC.PWR.ALL","COL.HRD.PRD.PCS","COL.HRD.DES.PCS","COL.LIG.PRD.PCS","COL.LIG.DES.PCS","COL.COK.IMP.PCS","COL.STM.IMP.PCS","COL.TOT.IMP.PCS","COL.CKE.IMP.PCS","COL.COK.EXP.PCS","COL.STM.EXP.PCS","COL.TOT.EXP.PCS","COL.CKE.EXP.PCS","COL.RAW.STK.PCS","COL.LIG.STK.PCS","COL.WCK.STK.PCS","COL.WST.STK.PCS","COL.CMI.STK.PCS","COL.NCM.STK.PCS","COL.CKE.STK.PCS","COL.RCC.STK.PCS","COL.RNC.STK.PCS","COL.HRD.PRD.CDR","COL.HRD.DES.CDR","COL.COK.PRD.CDR","COL.COK.DES.CDR","COL.STM.PRD.CDR","COL.STM.DES.CDR","COL.LIG.PRD.CDR","COL.LIG.DES.CDR","COL.HRD.STK.CDR","COL.LIG.STK.CDR"])

rows_after = df3_cleaned.shape[0]
print(f"Rows after cleaning (dropping): {rows_after}")
# Out:
# Removing rows with missing values
# Rows before cleaning: 315
# Rows after cleaning (dropping): 0

# %%
print("Removing rows with missing values")

rows_before = df.shape[0]
print(f"Rows before cleaning: {rows_before}")

df4_cleaned = df.dropna(subset=["DUE.CIL","DUE.GEN","DUE.CPSU"])

rows_after = df4_cleaned.shape[0]
print(f"Rows after cleaning (dropping): {rows_after}")
# Out:
# Removing rows with missing values
# Rows before cleaning: 315
# Rows after cleaning (dropping): 57

# %%
print("Removing rows with missing values")

rows_before = df.shape[0]
print(f"Rows before cleaning: {rows_before}")

df5_cleaned = df.dropna(subset=["CEM.PRD.OEA"])

rows_after = df5_cleaned.shape[0]
print(f"Rows after cleaning (dropping): {rows_after}")
# Out:
# Removing rows with missing values
# Rows before cleaning: 315
# Rows after cleaning (dropping): 242

# %%
print("Removing rows with missing values")

rows_before = df.shape[0]
print(f"Rows before cleaning: {rows_before}")

df6_cleaned = df.dropna(subset=["ELY.GEN.POS.TOT.NR","ELY.GEN.POS.TOT.WR","ELY.GEN.POS.TOT.SR","ELY.GEN.POS.TOT.ER","ELY.GEN.POS.TOT.NER","ELY.GEN.POS.TOT.India","ELY.DEM.POS.TOT.NR","ELY.DEM.POS.TOT.WR","ELY.DEM.POS.TOT.SR","ELY.DEM.POS.TOT.ER","ELY.DEM.POS.TOT.NER","ELY.DEM.POS.TOT.India","ELY.GEN.POS.THM","ELY.GEN.POS.COL","ELY.GEN.POS.LIG","ELY.GEN.POS.NUC","ELY.GEN.POS.GAS","ELY.GEN.POS.RES","ELY.GEN.POS.HYD","ELY.GEN.POS.SOL","ELY.GEN.POS.WND","ELY.GEN.POS.DEM","ELY.GEN.CEA.THM","ELY.GEN.CEA.NUC","ELY.GEN.CEA.HYD","ELY.GEN.CEA.BHU","ELY.PLF.CEA.THM","ELY.PLF.CEA.NUC","ELY.GEN.CEA.WND","ELY.GEN.CEA.SOL","ELY.GEN.CEA.BIO","ELY.GEN.CEA.BAG","ELY.GEN.CEA.SHY","ELY.GEN.CEA.OTH","ELY.GEN.CEA.TOT","ELY.CUF.HYD","ELY.CUF.COL","ELY.CUF.GAS","ELY.CUF.RES","ELY.CUF.NUC","ELY.CUF.SHY","ELY.CUF.SOL","ELY.CUF.WND","ELY.CUF.BIO"])

rows_after = df6_cleaned.shape[0]
print(f"Rows after cleaning (dropping): {rows_after}")
# Out:
# Removing rows with missing values
# Rows before cleaning: 315
# Rows after cleaning (dropping): 66

# %%
print("Removing rows with missing values")

rows_before = df.shape[0]
print(f"Rows before cleaning: {rows_before}")

df7_cleaned = df.dropna(subset=["IDY.PRD.OEA.COL.OLD","IDY.PRD.OEA.CRU.OLD","IDY.PRD.OEA.GAS.OLD","IDY.PRD.OEA.PET.OLD","IDY.PRD.OEA.FER.OLD","IDY.PRD.OEA.STL.OLD","IDY.PRD.OEA.CEM.OLD","IDY.PRD.OEA.ELY.OLD","IDY.PRD.OEA.COL","IDY.PRD.OEA.CRU","IDY.PRD.OEA.GAS","IDY.PRD.OEA.PET","IDY.PRD.OEA.FER","IDY.PRD.OEA.STL","IDY.PRD.OEA.CEM","IDY.PRD.OEA.ELY"])

rows_after = df7_cleaned.shape[0]
print(f"Rows after cleaning (dropping): {rows_after}")
# Out:
# Removing rows with missing values
# Rows before cleaning: 315
# Rows after cleaning (dropping): 72

# %%
print("Removing rows with missing values")

rows_before = df.shape[0]
print(f"Rows before cleaning: {rows_before}")

df8_cleaned = df.dropna(subset=["yyyymm"])

rows_after = df8_cleaned.shape[0]
print(f"Rows after cleaning (dropping): {rows_after}")
# Out:
# Removing rows with missing values
# Rows before cleaning: 315
# Rows after cleaning (dropping): 315

# %%
print('filling the missing values with 0')
df_filled = df1_cleaned.fillna(0)
df_filled = df2_cleaned.fillna(0)
df_filled = df3_cleaned.fillna(0)
df_filled = df4_cleaned.fillna(0)
df_filled = df5_cleaned.fillna(0)
df_filled = df6_cleaned.fillna(0)
df_filled = df7_cleaned.fillna(0)
df_filled = df8_cleaned.fillna(0)
print(df_filled[df_filled.isnull().any(axis=1)])
# Out:
# filling the missing values with 0
# Empty DataFrame
# Columns: [yyyymm, PET.LPG.CON, PET.NAP.CON, PET.MSP.CON, PET.ATF.CON, PET.SKO.CON, PET.HSD.CON, PET.LDO.CON, PET.LUB.CON, PET.SEC.CON, PET.BIT.CON, PET.PCK.CON, PET.OTH.CON, PET.TOT.CON, PET.TOT.PRD, GAS.PRD.GRS, GAS.PRD.NET, GAS.IMP, GAS.IMP.PRV, GAS.CON.PWR, GAS.CON.CGD, GAS.CON.REF, GAS.CON.INT, GAS.CON.TEA, GAS.CON.IND, GAS.CON.MFG, GAS.CON.OTH, GAS.CON.FRT, GAS.CON.PET, GAS.CON.SHR, GAS.CON.IRN, GAS.CON.TOT, COL.HRD.PRD.CIL.REV, COL.HRD.DES.CIL.REV, COL.HRD.PRD.CIL.PRV, COL.HRD.DES.CIL.PRV, COL.HRD.PRD.SCCL.PRV, COL.HRD.DES.SCCL.PRV, COL.HRD.PRD.SCCL.REV, COL.HRD.DES.SCCL.REV, COL.HRD.IMP.CIS, COL.HRD.EXP.CIS, COL.HRD.IMP.COK.DOC, COL.HRD.IMP.STM.DOC, COL.HRD.IMP.TOT.DOC, COL.HRD.PRD.PRV, COL.LIG.PRD.PRV, COL.HRD.PRD.REV, COL.LIG.PRD.REV, COL.HRD.PRD.ECL.MCL, COL.HRD.PRD.BCCL.MCL, COL.HRD.PRD.CCL.MCL, COL.HRD.PRD.NCL.MCL, COL.HRD.PRD.WCL.MCL, COL.HRD.PRD.SECL.MCL, COL.HRD.PRD.MCL.MCL, COL.HRD.PRD.NEC.MCL, COL.HRD.PRD.CIL.MCL, COL.HRD.PRD.SCCL.MCL, COL.HRD.PRD.CaptivesOthers.MCL, COL.HRD.PRD.GrandTotal.MCL, COL.HRD.DES.ECL.MCL, COL.HRD.DES.BCCL.MCL, COL.HRD.DES.CCL.MCL, COL.HRD.DES.NCL.MCL, COL.HRD.DES.WCL.MCL, COL.HRD.DES.SECL.MCL, COL.HRD.DES.MCL.MCL, COL.HRD.DES.NEC.MCL, COL.HRD.DES.CIL.MCL, COL.HRD.DES.SCCL.MCL, COL.HRD.DES.CaptivesOthers.MCL, COL.HRD.DES.GrandTotal.MCL, COL.LIG.PRD.NLCIL.MCL, COL.LIG.PRD.GMDCL.MCL, COL.LIG.PRD.GIPCL.MCL, COL.LIG.PRD.RSMML.MCL, COL.LIG.PRD.BLMCL.MCL, COL.LIG.PRD.GHCL.MCL, COL.LIG.PRD.VSLignite.MCL, COL.LIG.PRD.GSPL.MCL, COL.LIG.PRD.GrandTotal.MCL, COL.LIG.DES.NLCIL.MCL, COL.LIG.DES.GMDCL.MCL, COL.LIG.DES.GIPCL.MCL, COL.LIG.DES.RSMML.MCL, COL.LIG.DES.BLMCL.MCL, COL.LIG.DES.GHCL.MCL, COL.LIG.DES.VSLignite.MCL, COL.LIG.DES.GSPL.MCL, COL.LIG.DES.GrandTotal.MCL, COL.HRD.PRD.UNS, COL.LIG.PRD.UNS, COL.HRD.PRD.CAP.CAB, COL.HRD.PRD.CIL.MCL.YTD, COL.HRD.PRD.SCCL.MCL.YTD, COL.HRD.PRD.CAP.MCL.YTD, COL.HRD.PRD.OTH.MCL.YTD, COL.HRD.PRD.TOT.MCL.YTD, COL.HRD.DES.CIL.MCL.YTD, ...]
# Index: []
#
# [0 rows x 203 columns]

# %%
df.columns
# Out:
# Index(['yyyymm', 'PET.LPG.CON', 'PET.NAP.CON', 'PET.MSP.CON', 'PET.ATF.CON',
#        'PET.SKO.CON', 'PET.HSD.CON', 'PET.LDO.CON', 'PET.LUB.CON',
#        'PET.SEC.CON',
#        ...
#        'IDY.PRD.OEA.CEM.OLD', 'IDY.PRD.OEA.ELY.OLD', 'IDY.PRD.OEA.COL',
#        'IDY.PRD.OEA.CRU', 'IDY.PRD.OEA.GAS', 'IDY.PRD.OEA.PET',
#        'IDY.PRD.OEA.FER', 'IDY.PRD.OEA.STL', 'IDY.PRD.OEA.CEM',
#        'IDY.PRD.OEA.ELY'],
#       dtype='object', length=203)

# %%
df.info
# Out:
# <bound method DataFrame.info of      yyyymm  PET.LPG.CON  PET.NAP.CON  PET.MSP.CON  PET.ATF.CON  PET.SKO.CON  \
# 0    199804   394.468560   596.087000   447.684830   178.092280  1021.889150
# 1    199805   392.533620   709.010740   489.861050   177.902250  1128.395960
# 2    199806   381.081170   627.708910   461.986710   165.273900  1000.898400
# 3    199807   438.121520   806.934410   451.382820   168.707920   934.154420
# 4    199808   415.307680   750.952250   449.519060   169.776980   969.680470
# ..      ...          ...          ...          ...          ...          ...
# 310  202402  2607.690671  1142.266179  3022.599611   705.127891    36.109809
# 311  202403  2612.456364  1134.643700  3323.510147   757.865799    31.647722
# 312  202404  2369.754499  1216.994045  3284.506193   742.440807    26.731549
# 313  202405  2393.920452  1084.785855  3462.927638   743.315150    30.024985
# 314  202406  2304.951478  1072.294715  3296.147580   706.829286    36.375199
#
#      PET.HSD.CON  PET.LDO.CON  PET.LUB.CON  PET.SEC.CON  ...  \
# 0    3193.433810    89.100710    56.266910   835.622150  ...
# 1    3273.822260    99.722180    78.276240   951.926110  ...
# 2    3192.914950    99.901790    93.205370   930.760070  ...
# 3    2920.608970   108.887290    77.266000  1090.239400  ...
# 4    2625.253930   111.397420    88.296370  1060.638810  ...
# ..           ...          ...          ...          ...  ...
# 310  7442.683143    62.551236   335.901806   523.446371  ...
# 311  8007.097386    66.766067   376.440508   527.440956  ...
# 312  7924.990999    50.964542   375.627534   526.317381  ...
# 313  8407.652820    62.468792   341.470663   557.992635  ...
# 314  7983.876277    65.044229   353.808521   536.192539  ...
#
#      IDY.PRD.OEA.CEM.OLD  IDY.PRD.OEA.ELY.OLD  IDY.PRD.OEA.COL  \
# 0                    NaN                  NaN              NaN
# 1                    NaN                  NaN              NaN
# 2                    NaN                  NaN              NaN
# 3                    NaN                  NaN              NaN
# 4                    NaN                  NaN              NaN
# ..                   ...                  ...              ...
# 310                  NaN                  NaN           97.507
# 311                  NaN                  NaN          117.647
# 312                  NaN                  NaN           79.664
# 313                  NaN                  NaN           84.904
# 314                  NaN                  NaN              NaN
#
#      IDY.PRD.OEA.CRU  IDY.PRD.OEA.GAS  IDY.PRD.OEA.PET  IDY.PRD.OEA.FER  \
# 0                NaN              NaN              NaN              NaN
# 1                NaN              NaN              NaN              NaN
# 2                NaN              NaN              NaN              NaN
# 3                NaN              NaN              NaN              NaN
# 4                NaN              NaN              NaN              NaN
# ..               ...              ...              ...              ...
# 310         2331.962         2886.054        22430.840           3661.4
# 311         2503.734         3070.490        24886.792           3768.5
# 312         2421.348         2899.061        23355.738           3807.7
# 313         2472.400         3049.640        24013.230           4392.3
# 314              NaN              NaN              NaN              NaN
#
#      IDY.PRD.OEA.STL  IDY.PRD.OEA.CEM  IDY.PRD.OEA.ELY
# 0                NaN              NaN              NaN
# 1                NaN              NaN              NaN
# 2                NaN              NaN              NaN
# 3                NaN              NaN              NaN
# 4                NaN              NaN              NaN
# ..               ...              ...              ...
# 310          12797.0          37156.0        136784.82
# 311          13726.0          41968.0        149249.03
# 312          13118.0          36543.0        154932.88
# 313          13074.0          36386.0        166181.03
# 314              NaN              NaN              NaN
#
# [315 rows x 203 columns]>

# %%
coal = df2["CEA.DGR.COL"]
year= df2.yyyymmdd

# %%
df2['Year'] = df2['yyyymmdd'] // 100
df2['Month'] = df2['yyyymmdd'] % 100

# %%
df2['Financial_Year'] = df2.apply(
    lambda row: f"{row['Year']}-{row['Year'] + 1}" if row['Month'] >= 4 else f"{row['Year'] - 1}-{row['Year']}",
    axis=1
)
ap = df2.groupby('Financial_Year')["CEA.DGR.COL"].sum().reset_index()
ap.columns = ['Financial_Year', 'Coal_Electricity_Production']

print(ap)
# Out:
#        Financial_Year  Coal_Electricity_Production
# 0   201803.0-201804.0                    8304.3200
# 1   201804.0-201805.0                   84806.1100
# 2   201805.0-201806.0                   89327.3960
# 3   201806.0-201807.0                   78484.9563
# 4   201807.0-201808.0                   75778.3995
# ..                ...                          ...
# 78  202403.0-202404.0                  113898.4500
# 79  202404.0-202405.0                  116880.8100
# 80  202405.0-202406.0                  119439.2300
# 81  202406.0-202407.0                  111491.4500
# 82  202407.0-202408.0                   68939.3200
#
# [83 rows x 2 columns]

# %%
ap=ap.drop(index=range(0, 16))

ap=ap.reset_index(drop=True)
print(ap)
# Out:
#        Financial_Year  Coal_Electricity_Production
# 0   201906.0-201907.0                     86853.34
# 1   201907.0-201908.0                     79589.86
# 2   201908.0-201909.0                     74189.33
# 3   201909.0-201910.0                     70715.27
# 4   201910.0-201911.0                     71853.81
# ..                ...                          ...
# 62  202403.0-202404.0                    113898.45
# 63  202404.0-202405.0                    116880.81
# 64  202405.0-202406.0                    119439.23
# 65  202406.0-202407.0                    111491.45
# 66  202407.0-202408.0                     68939.32
#
# [67 rows x 2 columns]

# %%
ap=ap.drop(index=10)
ap
# Out:
#        Financial_Year  Coal_Electricity_Production
# 0   201906.0-201907.0                     86853.34
# 1   201907.0-201908.0                     79589.86
# 2   201908.0-201909.0                     74189.33
# 3   201909.0-201910.0                     70715.27
# 4   201910.0-201911.0                     71853.81
# ..                ...                          ...
# 62  202403.0-202404.0                    113898.45
# 63  202404.0-202405.0                    116880.81
# 64  202405.0-202406.0                    119439.23
# 65  202406.0-202407.0                    111491.45
# 66  202407.0-202408.0                     68939.32
#
# [66 rows x 2 columns]

# %%
grouped_data = ap.groupby('Financial_Year')['Coal_Electricity_Production'].sum()
plt.figure(figsize=(10, 6))
plt.plot(grouped_data.index, grouped_data.values)
plt.xlabel('Financial Year')
plt.ylabel('Coal Electricity Production (Million kWh)')
plt.title('Coal Electricity Production per Financial Year')
plt.xticks(rotation=75, ha='right')
plt.tight_layout()
plt.show()

# %%
GAS = df2["CEA.DGR.GAS"]
year= df2.yyyymmdd

# %%
df2['Year'] = df2['yyyymmdd'] // 100
df2['Month'] = df2['yyyymmdd'] // 100
df2['Day'] = df2['yyyymmdd'] // 100

# %%
df2['Financial_Year'] = df2.apply(
    lambda row: f"{row['Year']}-{row['Year'] + 1}" if row['Month'] >= 4 else f"{row['Year'] - 1}-{row['Year']}",
    axis=1
)

ap = df2.groupby('Financial_Year')["CEA.DGR.GAS"].sum().reset_index()
ap.columns = ['Financial_Year', 'Gas_Electricity_Production']

print(ap)
# Out:
#    Financial_Year  Gas_Electricity_Production
# 0   201804-201805                  4620.53000
# 1   201805-201806                  4755.76000
# 2   201806-201807                  4094.98745
# 3   201807-201808                  4028.14170
# 4   201808-201809                  3708.50990
# ..            ...                         ...
# 71  202403-202404                  2482.98000
# 72  202404-202405                  3680.61000
# 73  202405-202406                  5053.41000
# 74  202406-202407                  4603.74000
# 75  202407-202408                  1864.50000
#
# [76 rows x 2 columns]

# %%
 ap=ap.drop(index=range(0, 16))

 ap=ap.reset_index(drop=True)
print(ap)
# Out:
#    Financial_Year  Gas_Electricity_Production
# 0   201908-201909                     3975.36
# 1   201909-201910                     4379.26
# 2   201910-201911                     4272.11
# 3   201911-201912                     3806.99
# 4   201912-201913                     3582.57
# 5   202001-202002                     3404.65
# 6   202002-202003                     3638.86
# 7   202003-202004                     2425.66
# 8   202004-202005                        0.00
# 9   202005-202006                        0.00
# 10  202006-202007                     5079.43
# 11  202007-202008                     5310.97
# 12  202008-202009                     4360.10
# 13  202009-202010                     4397.62
# 14  202010-202011                     4787.35
# 15  202011-202012                     3838.27
# 16  202012-202013                     3507.75
# 17  202101-202102                     3028.91
# 18  202102-202103                     3124.25
# 19  202103-202104                     3971.58
# 20  202104-202105                     3693.83
# 21  202105-202106                     3474.57
# 22  202106-202107                     3449.26
# 23  202107-202108                     3371.64
# 24  202108-202109                     3626.05
# 25  202109-202110                     3462.01
# 26  202110-202111                     3632.66
# 27  202111-202112                     2322.30
# 28  202112-202113                     2376.83
# 29  202201-202202                     2322.65
# 30  202202-202203                     2202.25
# 31  202203-202204                     2505.10
# 32  202204-202205                     2900.21
# 33  202205-202206                     2457.18
# 34  202206-202207                     2321.75
# 35  202207-202208                     2001.21
# 36  202208-202209                     1956.62
# 37  202209-202210                     1750.04
# 38  202210-202211                     1584.51
# 39  202211-202212                     1768.66
# 40  202212-202213                     1977.62
# 41  202301-202302                     2020.73
# 42  202302-202303                     1814.65
# 43  202303-202304                     1848.10
# 44  202304-202305                     2315.53
# 45  202305-202306                     2832.50
# 46  202306-202307                     3094.93
# 47  202307-202308                     2256.78
# 48  202308-202309                     3552.34
# 49  202309-202310                     2863.13
# 50  202310-202311                     3265.37
# 51  202311-202312                     1650.77
# 52  202312-202313                     1934.95
# 53  202401-202402                     2551.28
# 54  202402-202403                     2372.08
# 55  202403-202404                     2482.98
# 56  202404-202405                     3680.61
# 57  202405-202406                     5053.41
# 58  202406-202407                     4603.74
# 59  202407-202408                     1864.50

# %%
ap=ap.drop(index=10)
ap
# Out:
#    Financial_Year  Gas_Electricity_Production
# 0   201908-201909                     3975.36
# 1   201909-201910                     4379.26
# 2   201910-201911                     4272.11
# 3   201911-201912                     3806.99
# 4   201912-201913                     3582.57
# 5   202001-202002                     3404.65
# 6   202002-202003                     3638.86
# 7   202003-202004                     2425.66
# 8   202004-202005                        0.00
# 9   202005-202006                        0.00
# 11  202007-202008                     5310.97
# 12  202008-202009                     4360.10
# 13  202009-202010                     4397.62
# 14  202010-202011                     4787.35
# 15  202011-202012                     3838.27
# 16  202012-202013                     3507.75
# 17  202101-202102                     3028.91
# 18  202102-202103                     3124.25
# 19  202103-202104                     3971.58
# 20  202104-202105                     3693.83
# 21  202105-202106                     3474.57
# 22  202106-202107                     3449.26
# 23  202107-202108                     3371.64
# 24  202108-202109                     3626.05
# 25  202109-202110                     3462.01
# 26  202110-202111                     3632.66
# 27  202111-202112                     2322.30
# 28  202112-202113                     2376.83
# 29  202201-202202                     2322.65
# 30  202202-202203                     2202.25
# 31  202203-202204                     2505.10
# 32  202204-202205                     2900.21
# 33  202205-202206                     2457.18
# 34  202206-202207                     2321.75
# 35  202207-202208                     2001.21
# 36  202208-202209                     1956.62
# 37  202209-202210                     1750.04
# 38  202210-202211                     1584.51
# 39  202211-202212                     1768.66
# 40  202212-202213                     1977.62
# 41  202301-202302                     2020.73
# 42  202302-202303                     1814.65
# 43  202303-202304                     1848.10
# 44  202304-202305                     2315.53
# 45  202305-202306                     2832.50
# 46  202306-202307                     3094.93
# 47  202307-202308                     2256.78
# 48  202308-202309                     3552.34
# 49  202309-202310                     2863.13
# 50  202310-202311                     3265.37
# 51  202311-202312                     1650.77
# 52  202312-202313                     1934.95
# 53  202401-202402                     2551.28
# 54  202402-202403                     2372.08
# 55  202403-202404                     2482.98
# 56  202404-202405                     3680.61
# 57  202405-202406                     5053.41
# 58  202406-202407                     4603.74
# 59  202407-202408                     1864.50

# %%
grouped_data = ap.groupby('Financial_Year')['Gas_Electricity_Production'].sum()
plt.figure(figsize=(10, 6))
plt.plot(grouped_data.index, grouped_data.values)
plt.xlabel('Financial Year')
plt.ylabel('Gas Electricity Production (Million kWh)')
plt.title('Gas Electricity Production per Financial Year')
plt.xticks(rotation=75, ha='right')
plt.tight_layout()
plt.show()

# %%
hydro = df2["CEA.DGR.HYD"]
year= df2.yyyymmdd

# %%
df2['Year'] = df2['yyyymmdd'] // 100
df2['Month'] = df2['yyyymmdd'] // 100
df2['Day'] = df2['yyyymmdd'] // 100

# %%
df2['Financial_Year'] = df2.apply(
    lambda row: f"{row['Year']}-{row['Year'] + 1}" if row['Month'] >= 4 else f"{row['Year'] - 1}-{row['Year']}",
    axis=1
)

ap = df2.groupby('Financial_Year')["CEA.DGR.HYD"].sum().reset_index()
ap.columns = ['Financial_Year', 'Hydro_Electricity_Production']

print(ap)
# Out:
#    Financial_Year  Hydro_Electricity_Production
# 0   201804-201805                    7522.33000
# 1   201805-201806                   10636.84760
# 2   201806-201807                   13272.36285
# 3   201807-201808                   15799.52050
# 4   201808-201809                   18644.43940
# ..            ...                           ...
# 71  202403-202404                    6927.99000
# 72  202404-202405                    7992.79000
# 73  202405-202406                   12259.58000
# 74  202406-202407                   13748.56000
# 75  202407-202408                   12166.54000
#
# [76 rows x 2 columns]

# %%
 ap=ap.drop(index=range(0, 16))

# %%
ap=ap.reset_index(drop=True)
print(ap)
# Out:
#    Financial_Year  Hydro_Electricity_Production
# 0   201908-201909                     19844.400
# 1   201909-201910                     20753.280
# 2   201910-201911                     15115.940
# 3   201911-201912                     10127.300
# 4   201912-201913                      8883.850
# 5   202001-202002                      8621.280
# 6   202002-202003                      8510.810
# 7   202003-202004                      5318.710
# 8   202004-202005                         0.000
# 9   202005-202006                         0.000
# 10  202006-202007                     17062.510
# 11  202007-202008                     17919.360
# 12  202008-202009                     19356.020
# 13  202009-202010                     18939.640
# 14  202010-202011                     13134.460
# 15  202011-202012                      8408.740
# 16  202012-202013                      8192.770
# 17  202101-202102                      7935.670
# 18  202102-202103                      7251.140
# 19  202103-202104                      8380.310
# 20  202104-202105                      8254.710
# 21  202105-202106                     11783.650
# 22  202106-202107                     15997.660
# 23  202107-202108                     18799.180
# 24  202108-202109                     20224.240
# 25  202109-202110                     17818.970
# 26  202110-202111                     15546.590
# 27  202111-202112                      9759.420
# 28  202112-202113                      8348.140
# 29  202201-202202                      7630.300
# 30  202202-202203                      7499.930
# 31  202203-202204                     10585.070
# 32  202204-202205                     11497.250
# 33  202205-202206                     12832.360
# 34  202206-202207                     13386.000
# 35  202207-202208                     19413.150
# 36  202208-202209                     23398.930
# 37  202209-202210                     21995.390
# 38  202210-202211                     16301.100
# 39  202211-202212                     10082.890
# 40  202212-202213                      8786.990
# 41  202301-202302                      8212.990
# 42  202302-202303                      8367.550
# 43  202303-202304                      7725.960
# 44  202304-202305                      8367.020
# 45  202305-202306                     11501.350
# 46  202306-202307                     14134.760
# 47  202307-202308                     17622.950
# 48  202308-202309                     21927.490
# 49  202309-202310                     16328.135
# 50  202310-202311                     11570.180
# 51  202311-202312                      6829.680
# 52  202312-202313                      6445.630
# 53  202401-202402                      6523.520
# 54  202402-202403                      5934.840
# 55  202403-202404                      6927.990
# 56  202404-202405                      7992.790
# 57  202405-202406                     12259.580
# 58  202406-202407                     13748.560
# 59  202407-202408                     12166.540

# %%
ap=ap.drop(index=10)
ap
# Out:
#    Financial_Year  Hydro_Electricity_Production
# 0   201908-201909                     19844.400
# 1   201909-201910                     20753.280
# 2   201910-201911                     15115.940
# 3   201911-201912                     10127.300
# 4   201912-201913                      8883.850
# 5   202001-202002                      8621.280
# 6   202002-202003                      8510.810
# 7   202003-202004                      5318.710
# 8   202004-202005                         0.000
# 9   202005-202006                         0.000
# 11  202007-202008                     17919.360
# 12  202008-202009                     19356.020
# 13  202009-202010                     18939.640
# 14  202010-202011                     13134.460
# 15  202011-202012                      8408.740
# 16  202012-202013                      8192.770
# 17  202101-202102                      7935.670
# 18  202102-202103                      7251.140
# 19  202103-202104                      8380.310
# 20  202104-202105                      8254.710
# 21  202105-202106                     11783.650
# 22  202106-202107                     15997.660
# 23  202107-202108                     18799.180
# 24  202108-202109                     20224.240
# 25  202109-202110                     17818.970
# 26  202110-202111                     15546.590
# 27  202111-202112                      9759.420
# 28  202112-202113                      8348.140
# 29  202201-202202                      7630.300
# 30  202202-202203                      7499.930
# 31  202203-202204                     10585.070
# 32  202204-202205                     11497.250
# 33  202205-202206                     12832.360
# 34  202206-202207                     13386.000
# 35  202207-202208                     19413.150
# 36  202208-202209                     23398.930
# 37  202209-202210                     21995.390
# 38  202210-202211                     16301.100
# 39  202211-202212                     10082.890
# 40  202212-202213                      8786.990
# 41  202301-202302                      8212.990
# 42  202302-202303                      8367.550
# 43  202303-202304                      7725.960
# 44  202304-202305                      8367.020
# 45  202305-202306                     11501.350
# 46  202306-202307                     14134.760
# 47  202307-202308                     17622.950
# 48  202308-202309                     21927.490
# 49  202309-202310                     16328.135
# 50  202310-202311                     11570.180
# 51  202311-202312                      6829.680
# 52  202312-202313                      6445.630
# 53  202401-202402                      6523.520
# 54  202402-202403                      5934.840
# 55  202403-202404                      6927.990
# 56  202404-202405                      7992.790
# 57  202405-202406                     12259.580
# 58  202406-202407                     13748.560
# 59  202407-202408                     12166.540

# %%
grouped_data = ap.groupby('Financial_Year')['Hydro_Electricity_Production'].sum()
plt.figure(figsize=(10, 6))
plt.plot(grouped_data.index, grouped_data.values)
plt.xlabel('Financial Year')
plt.ylabel('Hydro Electricity Production (Million kWh)')
plt.title('Hydro Electricity Production per Financial Year')
plt.xticks(rotation=75, ha='right')
plt.tight_layout()
plt.show()

# %%
Wind = df2["CEA.DGR.WND"]
year= df2.yyyymmdd

# %%
df2['Year'] = df2['yyyymmdd'] // 100
df2['Month'] = df2['yyyymmdd'] // 100
df2['Day'] = df2['yyyymmdd'] // 100

# %%
df2['Financial_Year'] = df2.apply(
    lambda row: f"{row['Year']}-{row['Year'] + 1}" if row['Month'] >= 4 else f"{row['Year'] - 1}-{row['Year']}",
    axis=1
)

ap = df2.groupby('Financial_Year')["CEA.DGR.WND"].sum().reset_index()
ap.columns = ['Financial_Year', 'Wind_Electricity_Production']

print(ap)
# Out:
#    Financial_Year  Wind_Electricity_Production
# 0   201804-201805                        0.000
# 1   201805-201806                        0.000
# 2   201806-201807                        0.000
# 3   201807-201808                        0.000
# 4   201808-201809                        0.000
# ..            ...                          ...
# 71  202403-202404                     4493.278
# 72  202404-202405                     4540.490
# 73  202405-202406                     7895.390
# 74  202406-202407                    10066.860
# 75  202407-202408                    10264.840
#
# [76 rows x 2 columns]

# %%
ap=ap.drop(index=range(0, 16))

# %%
ap=ap.reset_index(drop=True)
print(ap)
# Out:
#    Financial_Year  Wind_Electricity_Production
# 0   201908-201909                    8589.3900
# 1   201909-201910                    4931.8800
# 2   201910-201911                    1937.3200
# 3   201911-201912                    2598.7800
# 4   201912-201913                    3736.4300
# 5   202001-202002                    3204.0800
# 6   202002-202003                    3319.3400
# 7   202003-202004                    3244.2600
# 8   202004-202005                    3289.1800
# 9   202005-202006                    5867.9600
# 10  202006-202007                    7261.9600
# 11  202007-202008                    6489.8300
# 12  202008-202009                    8883.2800
# 13  202009-202010                    4492.6600
# 14  202010-202011                    3566.6600
# 15  202011-202012                    3038.4800
# 16  202012-202013                    3421.9100
# 17  202101-202102                    3306.8000
# 18  202102-202103                    2592.4700
# 19  202103-202104                    2660.6200
# 20  202104-202105                    3487.0640
# 21  202105-202106                    5885.1500
# 22  202106-202107                    9088.8680
# 23  202107-202108                   10718.2640
# 24  202108-202109                    8751.3170
# 25  202109-202110                    6425.9440
# 26  202110-202111                    2853.3530
# 27  202111-202112                    2742.0444
# 28  202112-202113                    3435.8340
# 29  202201-202202                    3299.0720
# 30  202202-202203                    2898.2500
# 31  202203-202204                    2987.5900
# 32  202204-202205                    4073.5700
# 33  202205-202206                    9369.5100
# 34  202206-202207                    9181.5800
# 35  202207-202208                    9839.8100
# 36  202208-202209                    8552.0160
# 37  202209-202210                    5966.0200
# 38  202210-202211                    3134.6260
# 39  202211-202212                    2440.3740
# 40  202212-202213                    3955.7800
# 41  202301-202302                    5037.2500
# 42  202302-202303                    3208.7800
# 43  202303-202304                    4165.4440
# 44  202304-202305                    4287.8700
# 45  202305-202306                    7017.5100
# 46  202306-202307                   11016.2400
# 47  202307-202308                   12162.6100
# 48  202308-202309                   12043.8800
# 49  202309-202310                    8652.9830
# 50  202310-202311                    3505.4000
# 51  202311-202312                    3397.5400
# 52  202312-202313                    4921.0740
# 53  202401-202402                    4008.0940
# 54  202402-202403                    4704.1310
# 55  202403-202404                    4493.2780
# 56  202404-202405                    4540.4900
# 57  202405-202406                    7895.3900
# 58  202406-202407                   10066.8600
# 59  202407-202408                   10264.8400

# %%
ap=ap.drop(index=10)
ap
# Out:
#    Financial_Year  Wind_Electricity_Production
# 0   201908-201909                    8589.3900
# 1   201909-201910                    4931.8800
# 2   201910-201911                    1937.3200
# 3   201911-201912                    2598.7800
# 4   201912-201913                    3736.4300
# 5   202001-202002                    3204.0800
# 6   202002-202003                    3319.3400
# 7   202003-202004                    3244.2600
# 8   202004-202005                    3289.1800
# 9   202005-202006                    5867.9600
# 11  202007-202008                    6489.8300
# 12  202008-202009                    8883.2800
# 13  202009-202010                    4492.6600
# 14  202010-202011                    3566.6600
# 15  202011-202012                    3038.4800
# 16  202012-202013                    3421.9100
# 17  202101-202102                    3306.8000
# 18  202102-202103                    2592.4700
# 19  202103-202104                    2660.6200
# 20  202104-202105                    3487.0640
# 21  202105-202106                    5885.1500
# 22  202106-202107                    9088.8680
# 23  202107-202108                   10718.2640
# 24  202108-202109                    8751.3170
# 25  202109-202110                    6425.9440
# 26  202110-202111                    2853.3530
# 27  202111-202112                    2742.0444
# 28  202112-202113                    3435.8340
# 29  202201-202202                    3299.0720
# 30  202202-202203                    2898.2500
# 31  202203-202204                    2987.5900
# 32  202204-202205                    4073.5700
# 33  202205-202206                    9369.5100
# 34  202206-202207                    9181.5800
# 35  202207-202208                    9839.8100
# 36  202208-202209                    8552.0160
# 37  202209-202210                    5966.0200
# 38  202210-202211                    3134.6260
# 39  202211-202212                    2440.3740
# 40  202212-202213                    3955.7800
# 41  202301-202302                    5037.2500
# 42  202302-202303                    3208.7800
# 43  202303-202304                    4165.4440
# 44  202304-202305                    4287.8700
# 45  202305-202306                    7017.5100
# 46  202306-202307                   11016.2400
# 47  202307-202308                   12162.6100
# 48  202308-202309                   12043.8800
# 49  202309-202310                    8652.9830
# 50  202310-202311                    3505.4000
# 51  202311-202312                    3397.5400
# 52  202312-202313                    4921.0740
# 53  202401-202402                    4008.0940
# 54  202402-202403                    4704.1310
# 55  202403-202404                    4493.2780
# 56  202404-202405                    4540.4900
# 57  202405-202406                    7895.3900
# 58  202406-202407                   10066.8600
# 59  202407-202408                   10264.8400

# %%
grouped_data = ap.groupby('Financial_Year')['Wind_Electricity_Production'].sum()
plt.figure(figsize=(10, 6))
plt.plot(grouped_data.index, grouped_data.values)
plt.xlabel('Financial Year')
plt.ylabel('Wind Electricity Production (Million kWh)')
plt.title('Wind Electricity Production per Financial Year')
plt.xticks(rotation=75, ha='right')
plt.tight_layout()
plt.show()

# %%
Solar = df2["CEA.DGR.SOL"]
year= df2.yyyymmdd

# %%
df2['Year'] = df2['yyyymmdd'] // 100
df2['Month'] = df2['yyyymmdd'] // 100
df2['Day'] = df2['yyyymmdd'] // 100

# %%
df2['Financial_Year'] = df2.apply(
    lambda row: f"{row['Year']}-{row['Year'] + 1}" if row['Month'] >= 4 else f"{row['Year'] - 1}-{row['Year']}",
    axis=1
)

ap = df2.groupby('Financial_Year')["CEA.DGR.SOL"].sum().reset_index()
ap.columns = ['Financial_Year', 'Solar_Electricity_Production']

print(ap)
# Out:
#    Financial_Year  Solar_Electricity_Production
# 0   201804-201805                       0.00000
# 1   201805-201806                       0.00000
# 2   201806-201807                       0.00000
# 3   201807-201808                       0.00000
# 4   201808-201809                       0.00000
# ..            ...                           ...
# 71  202403-202404                   11556.66234
# 72  202404-202405                   11329.22800
# 73  202405-202406                   12014.80000
# 74  202406-202407                   10760.28000
# 75  202407-202408                    7606.76000
#
# [76 rows x 2 columns]

# %%
ap=ap.drop(index=range(0, 16))

ap=ap.reset_index(drop=True)
print(ap)
# Out:
#    Financial_Year  Solar_Electricity_Production
# 0   201908-201909                   3092.790000
# 1   201909-201910                   3059.940000
# 2   201910-201911                   3236.390000
# 3   201911-201912                   3668.420000
# 4   201912-201913                   3666.820000
# 5   202001-202002                   4341.280000
# 6   202002-202003                   4613.130000
# 7   202003-202004                   4949.350000
# 8   202004-202005                   4783.270000
# 9   202005-202006                   5092.450000
# 10  202006-202007                   4358.570000
# 11  202007-202008                   4306.060000
# 12  202008-202009                   3861.340000
# 13  202009-202010                   4065.830000
# 14  202010-202011                   4470.090000
# 15  202011-202012                   4212.290000
# 16  202012-202013                   4506.130000
# 17  202101-202102                   4570.700000
# 18  202102-202103                   4933.231000
# 19  202103-202104                   5147.290000
# 20  202104-202105                   5860.000000
# 21  202105-202106                   5157.660000
# 22  202106-202107                   5291.280000
# 23  202107-202108                   4841.390000
# 24  202108-202109                   5220.790000
# 25  202109-202110                   5091.050000
# 26  202110-202111                   6006.810000
# 27  202111-202112                   4358.860000
# 28  202112-202113                   5358.900000
# 29  202201-202202                   6096.187000
# 30  202202-202203                   6510.510200
# 31  202203-202204                   5991.890000
# 32  202204-202205                   7326.520000
# 33  202205-202206                   7798.980000
# 34  202206-202207                   7937.110000
# 35  202207-202208                   6555.060000
# 36  202208-202209                   7051.810000
# 37  202209-202210                   7514.210900
# 38  202210-202211                   7994.170000
# 39  202211-202212                   7381.538000
# 40  202212-202213                   7600.900000
# 41  202301-202302                   8556.844000
# 42  202302-202303                   8933.430000
# 43  202303-202304                   9495.610000
# 44  202304-202305                   9572.180000
# 45  202305-202306                   9875.040000
# 46  202306-202307                   8880.970000
# 47  202307-202308                   7843.130000
# 48  202308-202309                   8934.360000
# 49  202309-202310                   8402.820000
# 50  202310-202311                   9427.760000
# 51  202311-202312                   7329.850000
# 52  202312-202313                   7987.254382
# 53  202401-202402                   8284.400000
# 54  202402-202403                   9741.750000
# 55  202403-202404                  11556.662340
# 56  202404-202405                  11329.228000
# 57  202405-202406                  12014.800000
# 58  202406-202407                  10760.280000
# 59  202407-202408                   7606.760000

# %%
ap=ap.drop(index=10)
ap
# Out:
#    Financial_Year  Solar_Electricity_Production
# 0   201908-201909                   3092.790000
# 1   201909-201910                   3059.940000
# 2   201910-201911                   3236.390000
# 3   201911-201912                   3668.420000
# 4   201912-201913                   3666.820000
# 5   202001-202002                   4341.280000
# 6   202002-202003                   4613.130000
# 7   202003-202004                   4949.350000
# 8   202004-202005                   4783.270000
# 9   202005-202006                   5092.450000
# 11  202007-202008                   4306.060000
# 12  202008-202009                   3861.340000
# 13  202009-202010                   4065.830000
# 14  202010-202011                   4470.090000
# 15  202011-202012                   4212.290000
# 16  202012-202013                   4506.130000
# 17  202101-202102                   4570.700000
# 18  202102-202103                   4933.231000
# 19  202103-202104                   5147.290000
# 20  202104-202105                   5860.000000
# 21  202105-202106                   5157.660000
# 22  202106-202107                   5291.280000
# 23  202107-202108                   4841.390000
# 24  202108-202109                   5220.790000
# 25  202109-202110                   5091.050000
# 26  202110-202111                   6006.810000
# 27  202111-202112                   4358.860000
# 28  202112-202113                   5358.900000
# 29  202201-202202                   6096.187000
# 30  202202-202203                   6510.510200
# 31  202203-202204                   5991.890000
# 32  202204-202205                   7326.520000
# 33  202205-202206                   7798.980000
# 34  202206-202207                   7937.110000
# 35  202207-202208                   6555.060000
# 36  202208-202209                   7051.810000
# 37  202209-202210                   7514.210900
# 38  202210-202211                   7994.170000
# 39  202211-202212                   7381.538000
# 40  202212-202213                   7600.900000
# 41  202301-202302                   8556.844000
# 42  202302-202303                   8933.430000
# 43  202303-202304                   9495.610000
# 44  202304-202305                   9572.180000
# 45  202305-202306                   9875.040000
# 46  202306-202307                   8880.970000
# 47  202307-202308                   7843.130000
# 48  202308-202309                   8934.360000
# 49  202309-202310                   8402.820000
# 50  202310-202311                   9427.760000
# 51  202311-202312                   7329.850000
# 52  202312-202313                   7987.254382
# 53  202401-202402                   8284.400000
# 54  202402-202403                   9741.750000
# 55  202403-202404                  11556.662340
# 56  202404-202405                  11329.228000
# 57  202405-202406                  12014.800000
# 58  202406-202407                  10760.280000
# 59  202407-202408                   7606.760000

# %%
grouped_data = ap.groupby('Financial_Year')['Solar_Electricity_Production'].sum()
plt.figure(figsize=(10, 6))
plt.plot(grouped_data.index, grouped_data.values)
plt.xlabel('Financial Year')
plt.ylabel('Solar Electricity Production (Million kWh)')
plt.title('Solar Electricity Production per Financial Year')
plt.xticks(rotation=75, ha='right')
plt.tight_layout()
plt.show()

# %%
data = {
    'Year': [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
    'Hydro': [574.170000, 597.720000, 596.600000, 622.250000, 625.230000, 631.500000, 640.690000, 657.720000, 651.380000, 636.140000, 619.330000],
    'Wind': [359.530000, 326.330000, 353.570000, 394.620000, 419.490000, 378.290000, 325.410000, 313.160000, 364.180000, 357.620000, 352.070000],
    'Solar': [255.800000, 264.900000, 265.780000, 266.110000, 282.590000, 287.810000, 288.210000, 296.120000, 281.650000, 267.760000, 234.160000]
}
df = pd.DataFrame(data)
df.set_index('Year', inplace=True)

plt.figure(figsize=(12, 6))

plt.plot(df.index, df['Hydro'], color='royalblue', label='Hydro')
plt.plot(df.index, df['Wind'], color='lightskyblue', label='Wind')
plt.plot(df.index, df['Solar'], color='khaki', label='Solar')

plt.title("India's Renewable Electricity Production by Source (2014-2024)")
plt.ylabel("TWh/year")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

plt.show()

# %%
data = {
    'Year': [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
    'Coal': [3228.510000, 3460.190000, 3616.560000, 3685.240000, 3699.740000, 3686.790000, 3650.260000, 3418.590000, 3524.080000, 3674.680000, 3801.080000],
    'Natural gas': [99.480000, 118.090000, 102.100000, 106.750000, 59.070000, 111.100000, 115.740000, 116, 69.120000, 62.650000, 58.940000],
    'Nuclear': [116.970000, 115.970000, 123.010000, 124.760000, 123.180000, 123.420000, 123.440000, 125.650000, 123.680000, 120.710000, 115.480000] 
}
df = pd.DataFrame(data)
df.set_index('Year', inplace=True)

plt.figure(figsize=(12, 6))

plt.plot(df.index, df['Coal'], color='royalblue', label='Coal')
plt.plot(df.index, df['Natural gas'], color='lightskyblue', label='Natural gas')
plt.plot(df.index, df['Nuclear'], color='khaki', label='Nuclear')

plt.title("India's Non-Renewable Electricity Production by Source (2014-2024)")
plt.ylabel("TWh/year")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

plt.show()

# %%
data = {
    'Year': [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
    'Coal': [3228.510000, 3460.190000, 3616.560000, 3685.240000, 3699.740000, 3686.790000, 3650.260000, 3418.590000, 3524.080000, 3674.680000, 3801.080000],
    'Hydro': [574.170000, 597.720000, 596.600000, 622.250000, 625.230000, 631.500000, 640.690000, 657.720000, 651.380000, 636.140000, 619.330000],
    'Natural gas': [99.480000, 118.090000, 102.100000, 106.750000, 59.070000, 111.100000, 115.740000, 116, 69.120000, 62.650000, 58.940000],
    'Wind': [359.530000, 326.330000, 353.570000, 394.620000, 419.490000, 378.290000, 325.410000, 313.160000, 364.180000, 357.620000, 352.070000],
    'Solar': [255.800000, 264.900000, 265.780000, 266.110000, 282.590000, 287.810000, 288.210000, 296.120000, 281.650000, 267.760000, 234.160000],
    'Other renewables': [413.550000, 431.840000, 452.060000, 448.250000, 446.510000, 485.190000, 494.770000, 540, 627.060000, 720.610000, 750.890000],
    'Nuclear': [116.970000, 115.970000, 123.010000, 124.760000, 123.180000, 123.420000, 123.440000, 125.650000, 123.680000, 120.710000, 115.480000]
}

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.stackplot(df['Year'], df['Coal'], df['Hydro'], df['Natural gas'], df['Wind'], df['Solar'], df['Other renewables'], df['Nuclear'],
              labels=['Coal', 'Hydro', 'Natural gas', 'Wind', 'Solar', 'Other renewables', 'Nuclear'])

plt.xlabel('Year')
plt.ylabel('Percentage of Electricity Generation')
plt.title("India's Total of Electricity Generation by Type")
plt.legend(loc='upper right')

plt.show()
